-- %%
%sql
REFRESH MATERIALIZED VIEW IDENTIFIER (:GOLD_CATALOG || "." || :GOLD_SCHEMA || "." || :FCT_DAILY_PROFILE_STATS_TABLE);

-- %%
%sql
REFRESH MATERIALIZED VIEW IDENTIFIER (:GOLD_CATALOG || "." || :GOLD_SCHEMA || "." || :FCT_DAILY_POST_STATS_TABLE);

-- %%
%sql
REFRESH MATERIALIZED VIEW IDENTIFIER (:GOLD_CATALOG || "." || :GOLD_SCHEMA || "." || :DIM_DATE_TABLE);

-- %%
%sql
REFRESH MATERIALIZED VIEW IDENTIFIER (:GOLD_CATALOG || "." || :GOLD_SCHEMA || "." || :DIM_TIMESTAMP_TABLE);
